# %%
from lex import *
from parse import *
import sys

def main():
    print("Teeny Tiny Compiler")
    file = input("pleas inter name of your file:")
    INPUT = open(file,'r' )


    
    # Initialize the lexer and parser.
    lexer = Lexer(INPUT.read())
    parser = Parser(lexer)

    parser.program() # Start the parser.
    print("Parsing completed.")

main()
# Out:
# Teeny Tiny Compiler
# pleas inter name of your file:teenytiny.txt
# PROGRAM
# STATEMENT-PRINT
# NEWLINE
# STATEMENT-INPUT
# NEWLINE
# STATEMENT-PRINT
# NEWLINE
# STATEMENT-LET
# EXPRESSION
# TERM
# UNARY
# PRIMARY (0)
# NEWLINE
# STATEMENT-LET
# EXPRESSION
# TERM
# UNARY
# PRIMARY (1)
# NEWLINE
# STATEMENT-WHILE
# COMPARISON
# EXPRESSION
# TERM
# UNARY
# PRIMARY (nums)
# EXPRESSION
# TERM
# UNARY
# PRIMARY (0)
# NEWLINE
# STATEMENT-PRINT
# EXPRESSION
# TERM
# UNARY
# PRIMARY (a)
# NEWLINE
# STATEMENT-LET
# EXPRESSION
# TERM
# UNARY
# PRIMARY (a)
# TERM
# UNARY
# PRIMARY (b)
# NEWLINE
# STATEMENT-LET
# EXPRESSION
# TERM
# UNARY
# PRIMARY (b)
# NEWLINE
# STATEMENT-LET
# EXPRESSION
# TERM
# UNARY
# PRIMARY (c)
# NEWLINE
# STATEMENT-LET
# EXPRESSION
# TERM
# UNARY
# PRIMARY (nums)
# TERM
# UNARY
# PRIMARY (1)
# NEWLINE
# NEWLINE
# Parsing completed.
